# %% [markdown]
# neo4j desktop 사전작업
#
# 1. version 4.4 설치
#
# 2. plugin에서 `APOC`, `Graph Data Science Library` install
#
# 3. import 폴더에 데이터 옮기기
#
# 4. conf에 `apoc.import.file.enabled=true` 추가 (자동 재부팅됨)
#
# 5. 재부팅 한번 더 하기 (함수가 바로 적용 안되는 경우가 있어서)
#
# 6. 아래 코드 돌리기 (제 작업환경은 python3.8 입니다)
#
# ---
#
# ## 1. connection
# > graphDB
# > >
# > close
#
# * **graphDB(uri, user, password)**: neo4j graph database에 연동하는 함수

# %%
from MygraphDB_v4 import graphDB
uri = "neo4j://localhost:7687"    # desktop으로 돌릴 시
# uri = "neo4j://172.16.200.28:7687"   # 서버로 돌릴 시
user = 'neo4j'
password = 'testneo4j'
db = graphDB(uri, user, password)
# Out:
# ---------------- Initializing NeoInterface -------------------
# Connection to neo4j://localhost:7687 established
# -- Successfully connected! --
# connection user name : neo4j
# current neo4j version  4.4.0

# %% [markdown]
# 빈 공간일때
# Total	752.00 KiB
# Database	752.00 KiB

# %% [markdown]
# ## 2. create
#
# * **add**: spo를 올리는 함수

# %%
db.add("ActivityNet_100.csv")  

## 기존 함수 add_object, add_spo 통합했음
## 함수 input: import경로에 업로드한 파일명으로 변경
# Out:
# Load the 91972 objects successfully.
# Load the 5613 relationships and 81268 spos successfully.
#
# total time elapsed:  7.901775121688843
# --please wait for generating page rank--

# %% [markdown]
# 아무것도 설정 안했을 때
# Total	752.00 KiB
# Database	752.00 KiB
#
# 패키지 인스톨 처음
# Total	852.22 KiB
# Database	848.66 KiB
#
# 데이터 최초 load
# Total	73.34 MiB
# Database	28.73 MiB

# %% [markdown]
# ## 3. search
#
# > get_description
# >
# > get_object_list
# >
# > get_predicate_list
# >
# > get_object
# >
# > get_spo
#
# **1) get_description**: neo4j에 현재 저장된 objects와 predicates의 정보를 보여주는 함수. object와 predicate의 평균 갯수, 최소 갯수, 최대 갯수 등을 출력한다.

# %%
cnt, info = db.get_description()
# Out:
# ----node and relation count----
# [{'node_count': 91972}, {'relationship_count': 81268}]
#
#
# ----Information for property and relationship----
# [{'node_label': ['object'], 'SampleSize': 9058, 'Avg_PropertyCount': 3.0, 'Min_PropertyCount': 3, 'Max_PropertyCount': 3, 'Avg_RelationshipCount': 1.725546478251278, 'Min_RelationshipCount': 0, 'Max_RelationshipCount': 19}]

# %% [markdown]
# **2) get_object_list**: db에 저장되어 있는 object의 목록을 출력하는 함수

# %%
db.get_object_list()
# Out:
# ['10 or more',
#  '',
#  'extension',
#  'booth',
#  'pushed',
#  'earned',
#  'computer screen',
#  'mom',
#  'more into',
#  'magenta',
#  'casually',
#  'company name',
#  'car door',
#  'atm',
#  'Parmesan cheese',
#  'drugged by',
#  'fridge',
#  'branch',
#  'fastened',
#  'fishing',
#  'barber chair',
#  'volunteers',
#  'snowslide',
#  'clapping',
#  'wandering',
#  'dumbbell',
#  'group of people',
#  'well trained',
#  'michelle li',
#  'robohandle',
#  'slackline',
#  'pulled out of',
#  'rooftop',
#  'spins',
#  'side tracked',
#  'allen key',
#  'pray',
#  'interlocking',
#  'waiters',
#  'other guys',
#  'dance performance',
#  'wrestling ring',
#  'almost fully cooked',
#  'hair care products',
#  'rapid',
#  'break dance routine',
#  'sauerkraut',
#  'art foil',
#  'golden retriever',
#  'falling down',
#  'rappelling',
#  'coloring',
#  'bunk',
#  'parasailer',
#  'sledding down',
#  'lumberjack things',
#  'trolley',
#  'edge of table',
#  'buoy',
#  'sorted',
#  'rock wall',
#  'rural area',
#  'Roman Reignss',
#  'burn',
#  'country roads',
#  'pan',
#  'how to grout',
#  'joyful',
#  'dodgers',
#  'machine room',
#  'skin',
#  'donated',
#  'letters',
#  'nail trimmer',
#  'belly dancer',
#  'toilet',
#  'night',
#  'piece of clothing',
#  '360',
#  'boars',
#  'filled',
#  'one after the other',
#  'karate moves',
#  'back paws',
#  'deep',
#  'bag',
#  'contact',
#  'pitchers',
#  'jump up and down',
#  'contact case',
#  'egg yolks',
#  'youth',
#  'tasty',
#  'hooping',
#  'roller skates',
#  'two handed',
#  'chocolate',
#  'laugh',
#  'scottish',
#  'different age groups',
#  'mixed',
#  'metal stick',
#  'river guide',
#  'elliptical',
#  'sumo outfit',
#  'news report',
#  'insulation',
#  'nail tape',
#  'ice ridden',
#  'underneath',
#  'pike',
#  'stationary bikes',
#  'bowing',
#  'humpy',
#  '2  feet',
#  'several',
#  'wrest',
#  'grinder',
#  'makeup source',
#  'side of court',
#  'Katty Perry',
#  'run towards',
#  'sliding on',
#  'walk off',
#  'winter storm',
#  'construction worker',
#  'flaming',
#  'fame',
#  'presenter',
#  'beaches',
#  'saved',
#  'basketball drill',
#  'deer',
#  'chalk marks',
#  'face',
#  'charger',
#  'hairspray',
#  'remainder',
#  'mother teresa',
#  'helped by',
#  'paned',
#  'shaved off',
#  'play button',
#  'suspenseful',
#  'swaying',
#  'inhaling',
#  'wall surface',
#  'scuba dive',
#  'palette',
#  'shoe shiner',
#  'baby brother',
#  'alongside',
#  'blazing',
#  'praise',
#  'couple',
#  'skates',
#  'bakery',
#  'paper work',
#  'wanting',
#  'wedding',
#  'deal',
#  'context',
#  'floor level',
#  'dominant',
#  'poker tokens',
#  'bot',
#  'framed glasses',
#  'switch',
#  'short',
#  'ornamented',
#  'eyelashes',
#  'glide shot',
#  'steam',
#  'pointing at',
#  'gift paper',
#  'base of',
#  'hong kong',
#  'pretty',
#  'button down',
#  'back to back',
#  'stethoscope',
#  'dodge ball',
#  'seeds',
#  'crystal',
#  'present',
#  'bathrooms',
#  'ways',
#  'pattern book',
#  'gymn',
#  'times',
#  'hot dog',
#  'snowcapped',
#  'word',
#  'run back',
#  'sets',
#  'cream',
#  'nursing',
#  'shoe shining',
#  'wide',
#  'salad pasta',
#  'capes',
#  'going on',
#  'zooming in',
#  'get away',
#  'liquor',
#  'twist',
#  'tennis net',
#  'power washing',
#  'crystal blue',
#  'braiding process',
#  'held',
#  'snow sleds',
#  'layer',
#  'gentle',
#  'patched',
#  'picture',
#  'surf',
#  'maxim',
#  'pit',
#  'curly hair',
#  'important',
#  'ferrigno',
#  'speed boat',
#  'acid',
#  'pong',
#  'host',
#  'clothing',
#  'victorious',
#  'adhesive strip',
#  'performance',
#  '67 meter',
#  'livestrong',
#  'piled',
#  'makeup case',
#  'zoom in on',
#  'gym mats',
#  'head lock',
#  'plant',
#  'three step',
#  'hockey stick',
#  'lawn utensil',
#  'precision',
#  'tutorial on',
#  'beige',
#  'basketball ball net',
#  'bubble bath',
#  'ropes',
#  'extend',
#  'car interior',
#  'aftershave',
#  'hillside',
#  'hair cuts',
#  'energy',
#  'stuffed toy',
#  'tattoo machine',
#  'assistants',
#  'underbelly',
#  '2004',
#  'air tank',
#  'argentinian',
#  'water vehicle',
#  'strategizing',
#  'bucked off',
#  'fresh',
#  'RPM',
#  'shed door',
#  'wallwik',
#  'arm hole',
#  'name template',
#  'backetball',
#  'manta',
#  'winter',
#  'polo match',
#  'on top of stove',
#  'crossing',
#  'escorted',
#  'gatorade',
#  'horn instruments',
#  'formal dress',
#  'wrestling match',
#  'turf',
#  'cascade',
#  'girls',
#  'nailpolish',
#  'great',
#  'panning',
#  'attributes',
#  'stone cold',
#  'footing',
#  'nutrition',
#  'complicated',
#  'reason',
#  'pet hair',
#  'series of swings',
#  'hosed down',
#  'tennis players',
#  'next to',
#  'continuously',
#  'scare',
#  'robot arm',
#  'sushi',
#  'news hosts',
#  'nail polish bottles',
#  'artistic',
#  'surrounding',
#  'jagermeister',
#  'gesturing',
#  'sidewalks',
#  'tutus',
#  'repeated',
#  'dodgeballs',
#  'smothered',
#  'medium',
#  'hazmat suit',
#  'on team',
#  'step back',
#  'stack of wood',
#  'baton',
#  'stay together',
#  'slice',
#  'weather map',
#  'inside of',
#  'foreman',
#  'attachments',
#  'stunt men',
#  'later',
#  'yoga ball',
#  'snow removal',
#  'forepaws',
#  'health',
#  'meat',
#  'gallop',
#  'on side of nails',
#  'listerine',
#  'stop',
#  'bird bath',
#  'united states',
#  'official',
#  'overgrown',
#  'adorned',
#  'effort',
#  'northern',
#  'pepperoni',
#  'dancing routine',
#  'pool deck',
#  'snow covered yard',
#  'document',
#  'scientist',
#  'tanks',
#  'right off',
#  'bagpipe players',
#  'dejected',
#  'source',
#  'handfuls',
#  'wrist watch',
#  'vanilla extract',
#  'heightened',
#  'pointing',
#  'sleeve',
#  'cowboy hats',
#  'rack',
#  'flying disc',
#  'owner',
#  'end product',
#  'sweatsuits',
#  'situations',
#  'kickball',
#  'space',
#  'headband',
#  'kleva',
#  'title',
#  'race track',
#  'shaving',
#  'on water',
#  'other places',
#  'off of',
#  'wording',
#  'button up',
#  'volleyball nets',
#  'uploaded to',
#  'cereal',
#  '15',
#  'see',
#  'wiper blades',
#  'racquet',
#  'arm wrestling clubs',
#  'tee shirts',
#  'eyeliner',
#  'garage doors',
#  'snowslides',
#  'arranged in',
#  'flowerbed',
#  'bandanas',
#  'brushing techniques',
#  'news person',
#  'sunny day',
#  'boarder',
#  'exactly like',
#  'taste',
#  'station',
#  'tag',
#  'opening scene',
#  'wrestling round',
#  'about to perform',
#  'second',
#  'headboard',
#  'gross',
#  'wildly',
#  'liquid soap',
#  'end of porch',
#  'sinks',
#  'high jump stick',
#  'dirt roads',
#  'accordion',
#  'lemonade stand',
#  'blackjack table',
#  'approach',
#  'turban',
#  'interviewed by',
#  'pleased',
#  'people',
#  'belly dancers',
#  'news reporters',
#  'ice rink',
#  'news story',
#  'high dive',
#  'poofed up',
#  'out of breath',
#  'thirty seconds',
#  'together',
#  'renew',
#  '10km',
#  'walmart',
#  'noises',
#  'mountainside',
#  'percussion',
#  'sleep',
#  'Andrei',
#  'row',
#  'bowling facility',
#  'zoomed in on',
#  'dyson',
#  'motobike',
#  'abandoned',
#  'insulting',
#  'experienced',
#  'wash sinks',
#  'billboard',
#  'page',
#  'folded',
#  'voda soda',
#  'heavy',
#  'bell pepper',
#  'tantrum',
#  '1980',
#  'baton routine',
#  'zebra',
#  'fluid',
#  'shirt',
#  'gift',
#  'kayak in',
#  'code of points',
#  'behind the scenes',
#  'dark green',
#  'seated on',
#  'wheelbarrow',
#  'flawless',
#  'dent fixing mechanism',
#  'ballroom',
#  'stack',
#  'last time',
#  'same',
#  'arm movements',
#  'leg exercise',
#  'zip lining',
#  'corral',
#  'reese',
#  'double flip',
#  'seasonal',
#  'intensely',
#  'backhanded',
#  'chaplin',
#  'gymnasts',
#  'shiners',
#  'wipe',
#  'materials list',
#  'ducking',
#  'handstand move',
#  'whipped',
#  'chewed',
#  'canoers',
#  'classroom',
#  'fast motion',
#  'left leg',
#  'photo shoot',
#  'scared',
#  'line up',
#  'hockey skills',
#  'clay court',
#  'seventeen',
#  'cleaning products',
#  'hole',
#  'ax blade',
#  'paddle surf',
#  'terrain',
#  'bell county expo center',
#  'lead drummer',
#  'facebook',
#  'emergency',
#  '22',
#  'fins',
#  'built out of',
#  'scoop',
#  'slot machine',
#  'rubber band',
#  'views',
#  'whiting',
#  'tiling',
#  'cat food',
#  'thread',
#  'deposit',
#  'of all levels',
#  'preteen',
#  'bottle cap',
#  'berries',
#  'catcher',
#  'furniture renovation',
#  'efficient',
#  'chords',
#  'wrestling rink',
#  'trash basket',
#  'football jersey',
#  'call',
#  'beat',
#  'steady',
#  'topless',
#  'mats',
#  'crashes',
#  'terraced',
#  'pole trimmer',
#  'croquet mallets',
#  'Sedona',
#  'vehicles',
#  'hills',
#  'we',
#  'trunks',
#  'sand castle',
#  'sickle',
#  'do double dutch',
#  'wooded areas',
#  'pier',
#  'seppe smits',
#  'in sky',
#  'run on',
#  'sparks',
#  'pig tails',
#  'on ground',
#  'weave',
#  'potato peeler',
#  'bulbs',
#  'task',
#  'hog',
#  'cricket players',
#  'magazines',
#  'missed',
#  'stir',
#  'TV clip',
#  'combination',
#  'notes',
#  'instruction',
#  'weightlifting strategies',
#  'limes',
#  'tight rope',
#  'news announcer',
#  'countertop',
#  'collection hopper bag',
#  'marathon',
#  'correctly',
#  'jumps',
#  'bite size pieces',
#  'redneck',
#  'easy bake',
#  'starting point',
#  'what she has to do',
#  'intermixed',
#  'security guard',
#  'bug',
#  'narration',
#  'arm pull ups',
#  'duct tape',
#  'removal',
#  'casserole dish',
#  'snow castle',
#  'part of',
#  'newscast table',
#  'entire',
#  'specialized',
#  'against',
#  'standing position',
#  'bumper cards',
#  'scantily clad',
#  'positioned',
#  'breeze',
#  'construction',
#  'oreo',
#  'waterboards',
#  'double uneven bars',
#  'martial arts dances',
#  'flattening',
#  'native',
#  'bath tub',
#  'rv',
#  'roof jacks',
#  'scrubbing brush',
#  'liquors',
#  'compilation',
#  'balding',
#  'volleyball net',
#  'sanitizer',
#  'warrior',
#  'cafe',
#  'cloth',
#  'uniforms',
#  'yards',
#  'action',
#  'gear',
#  'fashionable',
#  'chambord royale',
#  'molded',
#  'loose',
#  'biologist',
#  'cake',
#  'arabic',
#  'lying down',
#  'nail polish bottle',
#  'lower part',
#  'calendar',
#  'elderly',
#  'slide show',
#  'sports hammer',
#  'hair pins',
#  'famous',
#  'giraffe',
#  'red team',
#  'oncoming',
#  'pale',
#  'typed',
#  '2 ladies',
#  'swim in ocean',
#  'snow suit',
#  'snow shovel',
#  'every time',
#  'land pool',
#  'helmeted',
#  'sled down',
#  'log',
#  'ready to dive',
#  'pleasingly',
#  'volunteering',
#  'Kleva',
#  'ice fishing',
#  'lighthouse',
#  'hispanic',
#  'tennis club',
#  'bitters',
#  'club kids',
#  'camping place',
#  'waltz',
#  'target boards',
#  'single',
#  'table football',
#  'strength',
#  'spray bottle',
#  'ok',
#  'fencing suit',
#  'food coloring',
#  'dance routine',
#  'corona',
#  'working out',
#  'take out of',
#  'snowblow',
#  'basketballs',
#  'oddly',
#  'cliff bar',
#  'bubbling',
#  '75',
#  'stretches',
#  'soap',
#  'mounted',
#  'bathrobe',
#  'foot placers',
#  'agility things',
#  'meet',
#  'carpet tape',
#  'straightened',
#  'reply',
#  'diamond',
#  'zig zag',
#  'injury',
#  'wuzler cup',
#  'procession',
#  'window treatments',
#  'run up',
#  'pink',
#  'buffed onto',
#  'camera view',
#  'steffisburg',
#  'display case',
#  'covered with',
#  'jumpers',
#  'whiskey sour',
#  'foam pieces',
#  'tied back',
#  'jumping around',
#  'frames',
#  'leads',
#  'hammer throws',
#  'dibloc',
#  'elliptical machine',
#  'create',
#  'dog walk',
#  'defense',
#  'jumping up',
#  'lunges',
#  'sweet potato',
#  'speech',
#  'beer pong match',
#  'paused',
#  'waxing strips',
#  'engine',
#  'Perkovic',
#  'materials',
#  'motorboats',
#  'other wrestler',
#  'exterior',
#  'table legs',
#  'matadors',
#  'shoots',
#  'sunken',
#  '28',
#  'pins',
#  'shut put',
#  'indoor',
#  'lawn chairs',
#  'beaver brush',
#  'argue',
#  'music sheet',
#  'exclaim',
#  'versatile',
#  'curling iron',
#  'handwashing',
#  'kneeing',
#  'on hands and knees',
#  'tattoo pattern',
#  'contents of',
#  'phillips',
#  'car wash bay',
#  'in',
#  'metal plates',
#  'strategically',
#  'sandwich plate',
#  'budgie',
#  'exercises',
#  'journalists',
#  'lesson',
#  'starting line',
#  'device',
#  'toppings',
#  'retractable',
#  'Sentosa',
#  'hair do',
#  'coke',
#  'book shelf',
#  'ice pick',
#  'hanging',
#  'poker',
#  '177',
#  'playing field',
#  'joiner',
#  'sled on',
#  'red',
#  'snow slide',
#  'midsize',
#  'cream cheese',
#  'purpose',
#  'lengthwise',
#  'beanie hat',
#  'newspapers',
#  'nice',
#  'portable',
#  'packaging',
#  'paint machine',
#  'cave area',
#  'shooting at',
#  'weld',
#  'camouflaged',
#  'sea',
#  'deep end of',
#  'donut tubes',
#  'her',
#  'put together',
#  'occasionally',
#  'knife storage options',
#  'mallet pole',
#  'lego',
#  'splintered',
#  'bottom of board',
#  'kitchen area',
#  'vertical',
#  'plastic sheets',
#  'street lamps',
#  'bar bell',
#  'giggle',
#  'start',
#  'suburban',
#  'mall',
#  'slacks',
#  'mountains',
#  'backs',
#  'momentum',
#  'cleaning materials',
#  'lined up',
#  'gymnastic event',
#  'plucked',
#  'dominance',
#  'dish washing job',
#  '10 m',
#  'nail tools',
#  'weightlifting',
#  'rose bushes',
#  'walk',
#  'curvy',
#  'topics',
#  'unicorn',
#  'suction',
#  'sealant',
#  '12',
#  'circles',
#  'until',
#  'pitiful',
#  'sandwiches',
#  'sanding',
#  'pine straws',
#  'william',
#  'alameen',
#  'spandex clothing',
#  'rowing exercise machine',
#  'Bacardi',
#  'reading glasses',
#  'electronic',
#  'formations',
#  'stuffed animal',
#  '69',
#  'soccer game',
#  'ruck',
#  'surfboard',
#  'cinnamon powder',
#  'fence post',
#  'dangers',
#  'dance floor',
#  'vacuum attachment piece',
#  'rodeo ring',
#  'ice court',
#  'jump rope skills',
#  'topic',
#  'bus',
#  'fireplace',
#  'up to',
#  'horse shoes',
#  'court room',
#  'motorcyclist',
#  'sports events',
#  'judge',
#  'snowy hill',
#  'sit',
#  'websites',
#  'serum',
#  'table tennis professional',
#  'noise',
#  'loose curlers',
#  'hot dog stand',
#  'news casters',
#  'hand soap bottles',
#  'aerial view',
#  'all fours',
#  'crushing',
#  'in room',
#  'preparing',
#  'midway',
#  'freestyle running jumps',
#  'mess',
#  'spread out',
#  'cricketers',
#  'cornstarch',
#  'door frame',
#  'steam machine',
#  'stainless steel',
#  'tv shows',
#  'chips',
#  'driver',
#  'Hanks',
#  'wound up',
#  'ready to eat',
#  'grilled',
#  'croquet balls',
#  'sniff around',
#  'floorworks',
#  'distracted',
#  'gone',
#  'animals',
#  'direction',
#  'dobsons',
#  'usb',
#  'sandy',
#  'care',
#  'final championship game',
#  'cart wheels',
#  'tennis player',
#  'squatting jumps',
#  'anguish',
#  'base coat',
#  'member of',
#  'eye lenses',
#  'screw',
#  'scrubs',
#  'handball',
#  'redirected',
#  'some',
#  'sandbars',
#  'blindfolds',
#  'plaster',
#  'spark',
#  'menacing',
#  'kirt',
#  'pillows',
#  'punches',
#  'test',
#  'cement',
#  'camera angle',
#  'study',
#  'tool belt',
#  'salon stylist',
#  'dragon',
#  'dog park',
#  'cookie machine',
#  'stencils',
#  'black widow',
#  'silently',
#  'newsman',
#  'wood pieces',
#  'noodles',
#  'quirt',
#  'matches',
#  'out to the side',
#  'aerobic',
#  'angle',
#  'discuss long',
#  'celebrated',
#  'oegano',
#  'mallet poles',
#  'couch',
#  'unhook',
#  'hold',
#  'solid',
#  'comb',
#  'car owners',
#  'build',
#  'book bag',
#  'cream colored',
#  'stop clock',
#  'sides of head',
#  'boy',
#  'grooming table',
#  'consulting room',
#  'volleyball',
#  'break dancing routine',
#  'talking',
#  'ice',
#  'struggle',
#  '3 inches',
#  'buffer',
#  'beats',
#  'knitters',
#  'video clips',
#  'trained',
#  'netting',
#  'wind kite',
#  'city streets',
#  'brushteeth',
#  'sink drain',
#  'wrong',
#  'hard',
#  'cookie sheet',
#  'arm wrestling contest',
#  'one wheel',
#  'drop in',
#  'bumper',
#  'Wisp Snowboard Trip',
#  'city plaza',
#  'toy board',
#  ...]

# %% [markdown]
# **4) get_predicate_list**: db에 저장되어 있는 predicate의 목록을 출력하는 함수

# %%
db.get_predicate_list()
# Out:
# ['is',
#  'stand in',
#  'lead into',
#  'dance around',
#  'capture',
#  'lay on',
#  'in',
#  'demonstrate',
#  'point to',
#  'do',
#  'end with',
#  'move around',
#  'perform',
#  'sit down',
#  'with',
#  'walk out onto',
#  'film',
#  'go back to',
#  'turn around',
#  'sit on',
#  'play',
#  'stand next to',
#  'watch',
#  'hold',
#  'walk by',
#  'pose in front of',
#  'sit in',
#  'next to',
#  'pierce',
#  'have',
#  'rub',
#  'ride',
#  'past',
#  'walk',
#  'lean forward',
#  'cover',
#  'mop',
#  'set down',
#  'play with',
#  'walk into',
#  'kneel down on',
#  'speak to',
#  'mix up',
#  'measure',
#  'cut out of',
#  'walk down',
#  'twist',
#  'grab',
#  'place on',
#  'hit',
#  'pick up',
#  'throw back',
#  'against',
#  'into',
#  'lay down',
#  'sit up',
#  'flash to',
#  'show',
#  'wear',
#  'talk to',
#  'lay out',
#  'wrap in',
#  'sit behind',
#  'of',
#  'stand in front of',
#  'block',
#  'climb across',
#  'wave to',
#  'climb',
#  'jump down',
#  'stand on',
#  'on',
#  'pan over',
#  'ride down',
#  'turn off',
#  'slide down',
#  'see',
#  'climb up',
#  'land on',
#  'hang on',
#  'in middle of',
#  'smile at',
#  'sit back',
#  'cross',
#  'talk',
#  'get',
#  'talk with',
#  'end',
#  'put down',
#  'surround',
#  'cheer',
#  'give',
#  'shake',
#  'share',
#  'around',
#  'play in',
#  'fill with',
#  'take off',
#  'run to',
#  'look at',
#  'stop',
#  'come back',
#  'blow around',
#  'dribble',
#  'make',
#  'score',
#  'work out in',
#  'step on',
#  'turn back to',
#  'include',
#  'in front of',
#  'laugh',
#  'pad',
#  'along',
#  'ride around',
#  'place',
#  'pull',
#  'snowboard on',
#  'spin',
#  'slide across',
#  'go over',
#  'crash while',
#  'jump onto',
#  'bounce over',
#  'sit inside',
#  'from',
#  'drink',
#  'fall on',
#  'get back on',
#  'fall off',
#  'roll away',
#  'retrieve',
#  'put',
#  'buckle',
#  'push',
#  'use',
#  'present',
#  'prepare',
#  'dip into',
#  'pour into',
#  'stand by',
#  'take',
#  'mix',
#  'to',
#  'stand under',
#  'at',
#  'slice into',
#  'eat',
#  'chop on',
#  'chop',
#  'sit together',
#  'enjoy',
#  'display on',
#  'perform in front of',
#  'go by',
#  'talk on',
#  'pan above',
#  'across',
#  'perform on',
#  'rotate',
#  'jump over',
#  'walk along',
#  'run',
#  'on top of',
#  'slice',
#  'scrub out',
#  'turn on',
#  'rinse out',
#  'return',
#  'on side of',
#  'pin to',
#  'jog at',
#  'run through',
#  'speak into',
#  'go into detail with',
#  'speak',
#  'read',
#  'kneel down onto',
#  'sit on side of',
#  'dance together',
#  'dance along',
#  'end by',
#  'test',
#  'run inside',
#  'run outside',
#  'hit over',
#  'watch on side of',
#  'introduce',
#  'explain',
#  'walk across',
#  'swing at',
#  'miss',
#  'swing',
#  'throw',
#  'during',
#  'walk in',
#  'train in',
#  'sharpen',
#  'touch',
#  'outside',
#  'shovel',
#  'wag',
#  'try to help',
#  'exercise on',
#  'pass on front of',
#  'walk on',
#  'at bottom of',
#  'tap along with',
#  'tap with',
#  'finish',
#  'work in',
#  'fix',
#  'onto',
#  'talk about',
#  'cut',
#  'help',
#  'reach',
#  'go down',
#  'stand with',
#  'descend down',
#  'unhook',
#  'let',
#  'tie to',
#  'behind',
#  'sit around',
#  'fly',
#  'walk away with',
#  'bend from',
#  'flip',
#  'over',
#  'kneel in',
#  'use to',
#  'blow onto',
#  'walk in front of',
#  'sit at top of',
#  'start',
#  'reach bottom of',
#  'sit at',
#  'sing into',
#  'look up',
#  'smile',
#  'run down',
#  'plow into',
#  'walk away',
#  'repeat',
#  'run with',
#  'ride through',
#  'before',
#  'under',
#  'not break',
#  'pan around',
#  'ride in',
#  'zoom in on',
#  'down',
#  'train',
#  'kick',
#  'stand',
#  'kneel',
#  'kick back',
#  'stand to',
#  'hug',
#  'continue practicing',
#  'shoot at',
#  'hide behind',
#  'dance across',
#  'run across',
#  'go',
#  'wave at',
#  'begin to',
#  'run out into',
#  'dance in',
#  'leave',
#  'border',
#  'sing',
#  'get up',
#  'stand while doing',
#  'assist with',
#  'near',
#  'open',
#  'remove',
#  'lift',
#  'loosen',
#  'stand between',
#  'part',
#  'brush',
#  'braid',
#  'get in',
#  'run into',
#  'dance with',
#  'dance at',
#  'join in',
#  'play on',
#  'pass by',
#  'strum',
#  'move',
#  'sit by',
#  'between',
#  'strum with',
#  'comb',
#  'pose',
#  'walk around',
#  'throw up',
#  'meet back in',
#  'finish by',
#  'land in',
#  'wash',
#  'stand behind',
#  'look over to',
#  'attach to',
#  'see from',
#  'stand around',
#  'jump after',
#  'jump',
#  'knock down',
#  'inside',
#  'jump for',
#  'record',
#  'change',
#  'speed up',
#  'file',
#  'clip',
#  'paint',
#  'create',
#  'hand',
#  'side by side with',
#  'shoot',
#  'play as',
#  'ride over',
#  'laugh on',
#  'prep',
#  'feature on',
#  'follow by',
#  'pause',
#  'above',
#  'put on',
#  'mount on',
#  'participate in',
#  'record in',
#  'high five',
#  'after',
#  'walk towards',
#  'climb on',
#  'pan to',
#  'sit beside',
#  'teach',
#  'move along',
#  'ride on',
#  'carry',
#  'come close to',
#  'return to',
#  'go back into',
#  'step to side of',
#  'step from side to side',
#  'move in',
#  'follow',
#  'zoom in',
#  'look down',
#  'arrive at',
#  'slide on',
#  'stop inside',
#  'display in',
#  'fly at',
#  'back into',
#  'get ready for',
#  'come out of',
#  'set',
#  'look into',
#  'join',
#  'flash in',
#  'hit by',
#  'try to',
#  'swing in',
#  'for',
#  'stand outside by',
#  'cut down',
#  'move to front of',
#  'cut off',
#  'jump into',
#  'wrap around',
#  'enter',
#  'start running in',
#  'pour out onto',
#  'create while',
#  'jump on',
#  'photograph',
#  'ride past',
#  'surf in',
#  'catch',
#  'fall back on',
#  'slam between',
#  'through',
#  'apply',
#  'leave after',
#  'stack on',
#  'split',
#  'drive down',
#  'get out of',
#  'throw into',
#  'go into',
#  'wake up in',
#  'click on',
#  'lather',
#  'rinse',
#  'turn',
#  'wipe',
#  'dry',
#  'march on',
#  'powder',
#  'rub off',
#  'put into',
#  'form',
#  'until',
#  'bend',
#  'signal',
#  'continue',
#  'fight over',
#  'break away from',
#  'ride towards',
#  'rapell up',
#  'climb until',
#  'hold up',
#  'stand outside',
#  'light up',
#  'chase after',
#  'off',
#  'install',
#  'insert',
#  'paddle in',
#  'go swimming in',
#  'swim under',
#  'get back in',
#  'get ready to',
#  'head back to',
#  'trim',
#  'lay',
#  'look around',
#  'lay back',
#  'ride up',
#  'snowboard',
#  'shoot outside',
#  'lay down on',
#  'hallucinate',
#  'beside',
#  'draw on',
#  'draw with',
#  'wipe with',
#  'clean',
#  'transition into',
#  'fish through',
#  'surround by',
#  'walk away from',
#  'run up to',
#  'fill',
#  'add',
#  'mix with',
#  'bring parallel to',
#  'pull out',
#  'piece together',
#  'kneel on',
#  'move across',
#  'roll',
#  'wipe down',
#  'push back and forth',
#  'interview',
#  'speak on',
#  'spew down',
#  'spray',
#  'gather in',
#  'splash on',
#  'begin',
#  'show off',
#  'cheer for',
#  'up',
#  'without',
#  'applaud',
#  'win',
#  'bring back to',
#  'represent',
#  'compete in',
#  'move back and forth on',
#  'travel to',
#  'study to be',
#  'learn',
#  'trick',
#  'approach',
#  'jump off of',
#  'serve',
#  'walk over',
#  'become',
#  'bend down to',
#  'put up',
#  'put over',
#  'mark',
#  'get back',
#  'run along',
#  'throw to',
#  'pan up to',
#  'dance on',
#  'guide',
#  'back down',
#  'work out',
#  'sit next to',
#  'get to',
#  'solve',
#  'lead',
#  'climb down',
#  'walk up',
#  'walk up to',
#  'walk under',
#  'pat',
#  'line up',
#  'talk into',
#  'raise',
#  'prepare to',
#  'mount',
#  'spin on',
#  'dismount',
#  'swim in',
#  'try to keep',
#  'pull onto',
#  'pull on',
#  'look back to',
#  'congratulate',
#  'place in',
#  'drive',
#  'run next to',
#  'close',
#  'swim around',
#  'yell on',
#  'yell to',
#  'tattoo',
#  'step into',
#  'pour',
#  'show at bottom of',
#  'present in',
#  'dance inside',
#  'practice in',
#  'celebrate in',
#  'lock',
#  'flip off',
#  'clap',
#  'in air',
#  'try to bite',
#  'get onto',
#  'start getting',
#  'flow through',
#  'go along with',
#  'jump from',
#  'instruct',
#  'watch from',
#  'wait for',
#  'clean off',
#  'drive away from',
#  'fill in',
#  'go around',
#  'hang down from',
#  'look to right side of',
#  'keep',
#  'look to',
#  'stand on side',
#  'hold on',
#  'jump off',
#  'yell',
#  'walk off',
#  'bow gracefully before',
#  'stand near',
#  'point at',
#  'appear on',
#  'style',
#  'take down',
#  'pose with',
#  'pan in',
#  'squat in',
#  'show before',
#  'about',
#  'talk in',
#  'push into',
#  'face',
#  'say',
#  'skate on',
#  'skate in',
#  'park on',
#  'skate through',
#  'walk to',
#  'focus on',
#  'play at',
#  'stand beside',
#  'walk back to',
#  'at top of',
#  'push around',
#  'stop to',
#  'move sideways',
#  'extend',
#  'go back and forth',
#  'twirl',
#  'engage in',
#  'beat',
#  'pass in front of',
#  'mow',
#  'shave around',
#  'pet',
#  'run on',
#  'rake',
#  'jump around',
#  'play around',
#  'bite',
#  'fly on',
#  'spoon onto',
#  'peel',
#  'spin around',
#  'wash in',
#  'fall into',
#  'drop',
#  'spin with',
#  'stand ready',
#  'stand up',
#  'pour in',
#  'cook',
#  'add to',
#  'serve in',
#  'stroke',
#  'come',
#  'break into',
#  'tap',
#  'dance to',
#  'run in',
#  'play along',
#  'sing along',
#  'spread',
#  'from behind',
#  'cut off to',
#  'while',
#  'board through',
#  'stand in middle of',
#  'run around',
#  'talk in front of',
#  'graze behind',
#  'cap',
#  'separate',
#  'add into',
#  'sit with',
#  'navigate',
#  'spread on',
#  'start from',
#  'shave',
#  'hang from',
#  'inhale from',
#  'look like',
#  'stand at front of',
#  'lean on',
#  'assemble',
#  'adjust',
#  'reach under',
#  'work on',
#  'come in',
#  'take a look at',
#  'get off',
#  'head toward',
#  'canoe in',
#  'display',
#  'rest',
#  'launch',
#  'launch onto',
#  'run over',
#  'flash on',
#  'move with',
#  'arm wrestle on',
#  'shave with',
#  'swish',
#  'spit out',
#  'go to',
#  'get on',
#  'hand onto',
#  'climb to',
#  'unscrew',
#  'screw in',
#  'come onto',
#  'examine',
#  'mount in front of',
#  'spin in',
#  'drop on',
#  'throw across',
#  'fly across',
#  'pose around',
#  'goof around',
#  'bounce',
#  'celebrate with',
#  'towards',
#  'clink',
#  'drink from',
#  'pretend to',
#  'rearrange',
#  'fist bump',
#  'play between',
#  'assist',
#  'massage',
#  'lay down to side of',
#  'walk behind',
#  'watch on',
#  'bow to',
#  'blow',
#  'ride behind',
#  'hang onto',
#  'climb on top of',
#  'run at',
#  'stand to the side of',
#  'walk with',
#  'hold onto',
#  'let go of',
#  'out to',
#  'swim on',
#  'come up before',
#  'swim',
#  'repair',
#  'inspect',
#  'bring',
#  'knock off',
#  'gather around',
#  'feel',
#  'drop down',
#  'run behind',
#  'retreat to',
#  'cheer with',
#  'knit with',
#  'thread with',
#  'paddle downstream',
#  'is from',
#  'maintain',
#  'bend over',
#  'speak in front of',
#  'dive into',
#  'plaster',
#  'jump along',
#  'burn',
#  'work',
#  'hammer',
#  'sand on side of',
#  'stand on side of',
#  'dribble to',
#  'swim with',
#  'buy',
#  'look on',
#  'smoke',
#  'match',
#  'point',
#  'go under',
#  'crowd around',
#  'wave',
#  'follow around',
#  'cheer on',
#  'hand on',
#  'skip on',
#  'jump in',
#  'bow after',
#  'laugh at',
#  'put behind',
#  'talk as',
#  'gather on',
#  'gather to',
#  'dance',
#  'run up',
#  'hop on',
#  'show on',
#  'walk out',
#  'look before',
#  'soap up',
#  'ski',
#  'fall',
#  'stay upright',
#  'try',
#  'show as',
#  'shut',
#  'whisk',
#  'shape',
#  'roll in',
#  'roll up',
#  'put in',
#  'bend on',
#  'walk away in',
#  'attempt',
#  'perform in',
#  'warm up',
#  'vault',
#  'celebrate',
#  'show in',
#  'walk near',
#  'sit',
#  'fly off',
#  'chase',
#  'stick',
#  'shave down',
#  'fly past',
#  'chalk',
#  'stretch in',
#  'vacuum',
#  'go in',
#  'go all out',
#  'cut in',
#  'stand at',
#  'position',
#  'toss backward',
#  'toss',
#  'bend down',
#  'start running',
#  'rope to',
#  'run in front of',
#  'tie up',
#  'lasso',
#  'try to stand up',
#  'carve',
#  'move up and down',
#  'set up',
#  'appear in',
#  'land on back beside',
#  'fall over',
#  'step back onto',
#  'greet',
#  'roll around',
#  'stretch with',
#  'follow after',
#  'set on',
#  'put out',
#  'review',
#  'pass to',
#  'get rid of',
#  'full of',
#  'jump high',
#  'continue to',
#  'attach',
#  'show at',
#  'party at',
#  'surf',
#  'float past',
#  'lower',
#  'back up',
#  'wipe sweat',
#  'speak with',
#  'on right side of',
#  'climb to top of',
#  'pump air into',
#  'drips down',
#  'section',
#  'blow dry',
#  'scrub with',
#  'rinse with',
#  'dry off with',
#  'go towards',
#  'mark down',
#  'peel off',
#  'lay over',
#  'go up and down',
#  'lead to',
#  'surrounded by',
#  'align on',
#  'illustrate',
#  'sit in front of',
#  'step up to',
#  'aim',
#  'cough',
#  'serve across',
#  'pull down',
#  'kneel onto',
#  'appear',
#  'swim to',
#  'stand before',
#  'stare at',
#  'mess with',
#  'try on',
#  'close up',
#  'park',
#  'pole vault',
#  'tighten',
#  'flip in',
#  'dive in',
#  'swing on',
#  'come up on',
#  'apply to',
#  'stop at',
#  'pull away from',
#  'drive around',
#  'come to',
#  'fight',
#  'sit at bottom of',
#  'look in',
#  'water ski',
#  'let go',
#  'flip over',
#  'iron',
#  'punch',
#  'speak in',
#  'get inside',
#  'nod',
#  'mix in',
#  'stir',
#  'go on',
#  'fish',
#  'angle',
#  'handle',
#  'jump with',
#  'kick with',
#  'distract',
#  'monitor',
#  'wrestle',
#  'move up to',
#  'dump out',
#  'sit outside',
#  'run back and forth',
#  'run toward',
#  'up to',
#  'run after',
#  'parasail on',
#  'sail in',
#  'decorate',
#  'ad to',
#  'go up',
#  'kiss',
#  'use to embellish',
#  'on sidewalk',
#  'roll to',
#  'kneel next to',
#  'bring inside',
#  'paint along side',
#  'train to',
#  'go through',
#  'switch back and forth to',
#  'take out',
#  'smear',
#  'smile for',
#  'pout for',
#  'strike',
#  'ride near',
#  'paddle along',
#  'react to',
#  'tie down',
#  'at end of',
#  'bounce on',
#  'swim towards',
#  'surface in',
#  'pose for',
#  'down side of',
#  'walk to front of',
#  'get up from',
#  'along with',
#  'clap for',
#  'push along',
#  'lick',
#  'wend down',
#  'stand up with',
#  'take turns at',
#  'score with',
#  'receive',
#  'show under',
#  'lead up to',
#  'stand up to',
#  'sunbathe with',
#  'appear over',
#  'buff',
#  'shine',
#  'step onto',
#  'pivot',
#  'paddle',
#  'slide',
#  'sail on',
#  'paint around',
#  'smile to',
#  'bounce around',
#  'continue with',
#  'bump into',
#  'pour on',
#  'sprinkle over',
#  'sweep up',
#  'videotape',
#  'motion',
#  'come outside',
#  'wrap',
#  'ski down',
#  'appear by',
#  'kneel as',
#  'end up in',
#  'fall in',
#  'climb onto',
#  'proceed on',
#  'prepare for',
#  'fight in',
#  'come together',
#  'sled along',
#  'float in',
#  'tear through',
#  'cut back to',
#  'use in',
#  'pass',
#  'dive at',
#  'make repairs to',
#  'walk out of',
#  'play against',
#  'take place in',
#  'hold by',
#  'talk from',
#  'train with',
#  'slip',
#  ...]

# %% [markdown]
# **3) get_object**: db에 노드로 저장되어 있는 object들을 출력하는 함수
#
# > :param object:  The desired objects stored in the database.

# %%
db.get_object(object = 'man,woman')
# Out:
# total time elapsed:  2.096080780029297
#      object       video_id
# 0       man  v_t3zAh4NBVko
# 1       man  v_mn1ozn0j7D8
# 2     woman  v_oG4zf8dAQKw
# 3       man  v_OBbHkBVDX8Y
# 4     woman  v_QxsELAtsSWE
# ...     ...            ...
# 6657    man  v_EhxFw5Eb1VE
# 6658  woman  v_1BfYAuxv6Wk
# 6659    man  v_ueDoskgg2yw
# 6660  woman  v_2dFLbFsFyuY
# 6661    man  v_2dFLbFsFyuY
#
# [6662 rows x 2 columns]

# %%
db.get_spo()
# Out:
# video_id:
#
# subject:
# person
# object:
# poo;
# predicate:
# dive in
# How to link subjects and and objects?
# If you use AND, the spo satisfying both subject and object is searched. If you use OR, the spo satisfying either the subject or the object is searched.
# and
# How to link subjects and and predicates?
# If you use AND, the spo satisfying both subject and predicates is searched. If you use OR, the spo satisfying either the subject or the predicates is searched.
# or
# How to link predicates and and objects?
# If you use AND, the spo satisfying both predicates and objects is searched. If you use OR, the spo satisfying either the predicates or the objects is searched.
# or
# total time elapsed:  2.285370349884033
#          video_id                                   video_path  \
# 0   v_OtcJMIJTTx4  https://www.youtube.com/watch?v=OtcJMIJTTx4
# 1   v_pzZ4TGcMK1k  https://www.youtube.com/watch?v=pzZ4TGcMK1k
# 2   v_pzZ4TGcMK1k  https://www.youtube.com/watch?v=pzZ4TGcMK1k
# 3   v_XSDIekFXkv0  https://www.youtube.com/watch?v=XSDIekFXkv0
# 4   v_Uru0CastJqU  https://www.youtube.com/watch?v=Uru0CastJqU
# 5   v_Vx4ZW7Xseyg  https://www.youtube.com/watch?v=Vx4ZW7Xseyg
# 6   v_gRqvh21b8Hw  https://www.youtube.com/watch?v=gRqvh21b8Hw
# 7   v_iwHZqcYwZYU  https://www.youtube.com/watch?v=iwHZqcYwZYU
# 8   v_ouqYXdtEuCI  https://www.youtube.com/watch?v=ouqYXdtEuCI
# 9   v_hpU50i4WBK8  https://www.youtube.com/watch?v=hpU50i4WBK8
# 10  v_bqsWU8HqpxE  https://www.youtube.com/watch?v=bqsWU8HqpxE
# 11  v_SfYJTxMRKDE  https://www.youtube.com/watch?v=SfYJTxMRKDE
# 12  v_bqDxblFvgro  https://www.youtube.com/watch?v=bqDxblFvgro
# 13  v_Kwhp0DNop9I  https://www.youtube.com/watch?v=Kwhp0DNop9I
# 14  v_yCqe0J1xgyc  https://www.youtube.com/watch?v=yCqe0J1xgyc
# 15  v_yCqe0J1xgyc  https://www.youtube.com/watch?v=yCqe0J1xgyc
# 16  v_5ObgpPDmVPA  https://www.youtube.com/watch?v=5ObgpPDmVPA
# 17  v_4avZ79LB5n4  https://www.youtube.com/watch?v=4avZ79LB5n4
#
#                                              captions  \
# 0   Then the little girl jumps, flip and dives in ...
# 1   People stand on the border of the diving board...
# 2    Swimmers jump from the diving board, they spi...
# 3    After, the boy stands on the trampoline with ...
# 4   A person is seen walking forward and jumping u...
# 5   A guy is diving off a diving board doing flips...
# 6    Then, above from the dive board two swimmers ...
# 7    Then, the man flips three times and and dive ...
# 8                  We then see the kids diving again.
# 9    They dive in and are able to look at all the ...
# 10   Two men are boxing, then people gather, men p...
# 11   People dive in the river, and then rest while...
# 12   Then different men are shown diving in slow m...
# 13   peolpe are scuba diving in the sea next to th...
# 14   Next are two girls representing Italy diving ...
# 15  We see two girls representing China standing o...
# 16  woman is in sea scubadiving and a man is behin...
# 17   They get in a unique position and then simult...
#
#                                  spo               frame
# 0   [[girl, dive in, swimming pool]]      [[4.77, 7.96]]
# 1         [[people, dive in, water]]     [[9.22, 79.28]]
# 2       [[swimmers, dive in, water]]  [[156.71, 184.37]]
# 3            [[boy, dive in, water]]     [[22.01, 33.4]]
# 4          [[person, dive in, pool]]        [[0, 10.38]]
# 5            [[guy, dive in, flips]]        [[0, 164.4]]
# 6         [[person, dive in, water]]    [[19.54, 59.41]]
# 7             [[man, dive in, pool]]      [[4.87, 8.52]]
# 8           [[kids, dive in, water]]     [[49.57, 68.6]]
# 9        [[people, dive in, corals]]    [[28.89, 60.08]]
# 10           [[man, dive in, water]]        [[0, 81.48]]
# 11        [[people, dive in, river]]  [[163.35, 227.76]]
# 12     [[men, dive in, slow motion]]   [[28.77, 160.54]]
# 13          [[people, dive in, sea]]    [[6.84, 195.47]]
# 14             [[girls, dive in, 2]]   [[98.64, 147.46]]
# 15        [[girls, dive in, unison]]        [[0, 45.83]]
# 16           [[woman, dive in, sea]]        [[0, 11.17]]
# 17     [[people, dive in, together]]      [[3.83, 6.75]]
